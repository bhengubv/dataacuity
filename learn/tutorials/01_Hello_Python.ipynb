# %% [markdown]
# # Welcome to Python!
#
# Hi there, young coder! Today you're going to learn how to talk to a computer using Python.
#
# ## Your First Code
#
# Click on the code box below and press **Shift + Enter** to run it!

# %%
print("Hello, World!")

# %% [markdown]
# ## WOW! You just wrote code!
#
# The computer said "Hello, World!" because you told it to!
#
# ### Try This:
# Change the message to say hello to YOU! Replace "World" with your name:

# %%
print("Hello, [Your Name Here]!")

# %% [markdown]
# ## Making the Computer Do Math
#
# Python is really good at math! Try these:

# %%
# Adding numbers
print(2 + 2)

# %%
# How old will you be in 10 years?
my_age = 7
print("In 10 years I will be", my_age + 10)

# %% [markdown]
# ### Your Turn!
#
# Change `my_age` to YOUR age and run the code again!

# %% [markdown]
# ## What You Learned
#
# - `print()` tells the computer to show something on the screen
# - You can put words in quotes like `"Hello"`
# - You can do math with `+`, `-`, `*`, `/`
# - You can save things in **variables** like `my_age = 7`
#
# ## Ready for More?
#
# Go to the next lesson: **Drawing with Turtle!**
